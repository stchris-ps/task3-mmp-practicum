# %%
def f(**kwargs):
    del kwargs['x']
    print(kwargs)

# %%
x=0
c=9

# %%
f(x=9,c=0)
# Out:
# {'c': 0}

# %%
s=f(x,c)

# %%
s is None
# Out:
# True

# %%
j=[5,5,5,5,5]

# %%
j.clear()

# %%
j
# Out:
# []

# %%
hh=8

# %%
hh
# Out:
# 8

# %%
round(13.2345,3)
# Out:
# 13.235

# %%
plt.figure(figsize=(9,5))
plt.plot(range(accurac), accurac)
plt.xlabel('number of trees')
plt.ylabel('accuracy(RMSE)')
plt.grid()
